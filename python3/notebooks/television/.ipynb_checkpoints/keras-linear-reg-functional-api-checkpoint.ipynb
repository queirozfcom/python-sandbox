# %% [markdown]
# http://www.stat.yale.edu/Courses/1997-98/101/linreg.htm

# %%
import pandas as pd

import numpy as np
import keras

from matplotlib import pyplot as plt

from keras.layers import Input, Dense
from keras.models import Model

from sklearn.preprocessing import StandardScaler, MinMaxScaler, Normalizer

# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv("data.csv")

# %%
df
# Out:
#             Country  Life Expectancy People per Television  \
# 0         Argentina             70.5                     4
# 1        Bangladesh             53.5                   315
# 2            Brazil             65.0                     4
# 3            Canada             76.5                   1.7
# 4             China             70.0                     8
# 5          Colombia             71.0                   5.6
# 6             Egypt             60.5                    15
# 7          Ethiopia             51.5                   503
# 8            France             78.0                   2.6
# 9           Germany             76.0                   2.6
# 10            India             57.5                    44
# 11        Indonesia             61.0                    24
# 12             Iran             64.5                    23
# 13            Italy             78.5                   3.8
# 14            Japan             79.0                   1.8
# 15            Kenya             61.0                    96
# 16     Korea, North             70.0                    90
# 17     Korea, South             70.0                   4.9
# 18           Mexico             72.0                   6.6
# 19          Morocco             64.5                    21
# 20  Myanmar (Burma)             54.5                   592
# 21         Pakistan             56.5                    73
# 22             Peru             64.5                    14
# 23      Philippines             64.5                   8.8
# 24           Poland             73.0                   3.9
# 25          Romania             72.0                     6
# 26           Russia             69.0                   3.2
# 27     South Africa             64.0                    11
# 28            Spain             78.5                   2.6
# 29            Sudan             53.0                    23
# 30           Taiwan             75.0                   3.2
# 31         Tanzania             52.5                     *
# 32         Thailand             68.5                    11
# 33           Turkey             70.0                     5
# 34          Ukraine             70.5                     3
# 35   United Kingdom             76.0                     3
# 36    United States             75.5                   1.3
# 37        Venezuela             74.5                   5.6
# 38          Vietnam             65.0                    29
# 39            Zaire             54.0                     *
#
#     People per Physician  Female Life Expectancy  Male Life Expectancy
# 0                    370                      74                    67
# 1                   6166                      53                    54
# 2                    684                      68                    62
# 3                    449                      80                    73
# 4                    643                      72                    68
# 5                   1551                      74                    68
# 6                    616                      61                    60
# 7                  36660                      53                    50
# 8                    403                      82                    74
# 9                    346                      79                    73
# 10                  2471                      58                    57
# 11                  7427                      63                    59
# 12                  2992                      65                    64
# 13                   233                      82                    75
# 14                   609                      82                    76
# 15                  7615                      63                    59
# 16                   370                      73                    67
# 17                  1066                      73                    67
# 18                   600                      76                    68
# 19                  4873                      66                    63
# 20                  3485                      56                    53
# 21                  2364                      57                    56
# 22                  1016                      67                    62
# 23                  1062                      67                    62
# 24                   480                      77                    69
# 25                   559                      75                    69
# 26                   259                      74                    64
# 27                  1340                      67                    61
# 28                   275                      82                    75
# 29                 12550                      54                    52
# 30                   965                      78                    72
# 31                 25229                      55                    50
# 32                  4883                      71                    66
# 33                  1189                      72                    68
# 34                   226                      75                    66
# 35                   611                      79                    73
# 36                   404                      79                    72
# 37                   576                      78                    71
# 38                  3096                      67                    63
# 39                 23193                      56                    52

# %%
df.columns,df.dtypes
# Out:
# (Index(['Country', 'Life Expectancy', 'People per Television',
#         'People per Physician', 'Female Life Expectancy',
#         'Male Life Expectancy'],
#        dtype='object'), Country                    object
#  Life Expectancy           float64
#  People per Television      object
#  People per Physician        int64
#  Female Life Expectancy      int64
#  Male Life Expectancy        int64
#  dtype: object)

# %%
# df["People per Television"] = df["People per Television"].as_numeric
df["People per Television"] = pd.to_numeric(df["People per Television"],errors='coerce')

# %%
df = df.dropna()

# %%
df
# Out:
#             Country  Life Expectancy  People per Television  \
# 0         Argentina             70.5                    4.0
# 1        Bangladesh             53.5                  315.0
# 2            Brazil             65.0                    4.0
# 3            Canada             76.5                    1.7
# 4             China             70.0                    8.0
# 5          Colombia             71.0                    5.6
# 6             Egypt             60.5                   15.0
# 7          Ethiopia             51.5                  503.0
# 8            France             78.0                    2.6
# 9           Germany             76.0                    2.6
# 10            India             57.5                   44.0
# 11        Indonesia             61.0                   24.0
# 12             Iran             64.5                   23.0
# 13            Italy             78.5                    3.8
# 14            Japan             79.0                    1.8
# 15            Kenya             61.0                   96.0
# 16     Korea, North             70.0                   90.0
# 17     Korea, South             70.0                    4.9
# 18           Mexico             72.0                    6.6
# 19          Morocco             64.5                   21.0
# 20  Myanmar (Burma)             54.5                  592.0
# 21         Pakistan             56.5                   73.0
# 22             Peru             64.5                   14.0
# 23      Philippines             64.5                    8.8
# 24           Poland             73.0                    3.9
# 25          Romania             72.0                    6.0
# 26           Russia             69.0                    3.2
# 27     South Africa             64.0                   11.0
# 28            Spain             78.5                    2.6
# 29            Sudan             53.0                   23.0
# 30           Taiwan             75.0                    3.2
# 32         Thailand             68.5                   11.0
# 33           Turkey             70.0                    5.0
# 34          Ukraine             70.5                    3.0
# 35   United Kingdom             76.0                    3.0
# 36    United States             75.5                    1.3
# 37        Venezuela             74.5                    5.6
# 38          Vietnam             65.0                   29.0
#
#     People per Physician  Female Life Expectancy  Male Life Expectancy
# 0                    370                      74                    67
# 1                   6166                      53                    54
# 2                    684                      68                    62
# 3                    449                      80                    73
# 4                    643                      72                    68
# 5                   1551                      74                    68
# 6                    616                      61                    60
# 7                  36660                      53                    50
# 8                    403                      82                    74
# 9                    346                      79                    73
# 10                  2471                      58                    57
# 11                  7427                      63                    59
# 12                  2992                      65                    64
# 13                   233                      82                    75
# 14                   609                      82                    76
# 15                  7615                      63                    59
# 16                   370                      73                    67
# 17                  1066                      73                    67
# 18                   600                      76                    68
# 19                  4873                      66                    63
# 20                  3485                      56                    53
# 21                  2364                      57                    56
# 22                  1016                      67                    62
# 23                  1062                      67                    62
# 24                   480                      77                    69
# 25                   559                      75                    69
# 26                   259                      74                    64
# 27                  1340                      67                    61
# 28                   275                      82                    75
# 29                 12550                      54                    52
# 30                   965                      78                    72
# 32                  4883                      71                    66
# 33                  1189                      72                    68
# 34                   226                      75                    66
# 35                   611                      79                    73
# 36                   404                      79                    72
# 37                   576                      78                    71
# 38                  3096                      67                    63

# %%
# x = ppl/television
# y = ppl/doctor

x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

x.shape,y.shape
# Out:
# ((38, 1), (38, 1))

# %%
x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

sc = StandardScaler()

x_ = sc.fit_transform(x)
y_ = sc.fit_transform(y)

inputs = Input(shape=(1,))
preds = Dense(1,activation='linear')(inputs)

model = Model(inputs=inputs,outputs=preds)
sgd=keras.optimizers.SGD()
model.compile(optimizer=sgd ,loss='mse')
model.fit(x_,y_, batch_size=1, verbose=0, shuffle=False)
plt.scatter(x_,y_,color='black')
plt.plot(x_,model.predict(x_), color='blue', linewidth=3)
# Out:
# /home/felipe/tf-venv3/lib/python3.5/site-packages/sklearn/utils/validation.py:429: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, _DataConversionWarning)
# (array([[-0.37302506],
#         [ 2.04492696],
#         [-0.37302506],
#         [-0.39090702],
#         [-0.34192599],
#         [-0.36058543],
#         [-0.28750264],
#         [ 3.50658284],
#         [-0.38390973],
#         [-0.38390973],
#         [-0.06203444],
#         [-0.21752975],
#         [-0.22530452],
#         [-0.37458001],
#         [-0.39012954],
#         [ 0.34225335],
#         [ 0.29560476],
#         [-0.36602777],
#         [-0.35281067],
#         [-0.24085405],
#         [ 4.19853695],
#         [ 0.16343375],
#         [-0.2952774 ],
#         [-0.33570618],
#         [-0.37380253],
#         [-0.35747553],
#         [-0.37924487],
#         [-0.3186017 ],
#         [-0.38390973],
#         [-0.22530452],
#         [-0.37924487],
#         [-0.3186017 ],
#         [-0.36525029],
#         [-0.38079982],
#         [-0.38079982],
#         [-0.39401692],
#         [-0.36058543],
#         [-0.17865592]]), array([[-0.41796562],
#         [ 0.52693597],
#         [-0.3667753 ],
#         [-0.40508653],
#         [-0.37345939],
#         [-0.22543133],
#         [-0.3778611 ],
#         [ 5.49826605],
#         [-0.41258575],
#         [-0.42187826],
#         [-0.07544695],
#         [ 0.73251238],
#         [ 0.00948986],
#         [-0.44030025],
#         [-0.37900229],
#         [ 0.76316137],
#         [-0.41796562],
#         [-0.30449918],
#         [-0.38046953],
#         [ 0.3161427 ],
#         [ 0.08986192],
#         [-0.09289078],
#         [-0.3126505 ],
#         [-0.30515129],
#         [-0.40003271],
#         [-0.38715362],
#         [-0.43606157],
#         [-0.25982992],
#         [-0.43345314],
#         [ 1.56769714],
#         [-0.32096486],
#         [ 0.31777297],
#         [-0.28444692],
#         [-0.44144144],
#         [-0.37867624],
#         [-0.41242272],
#         [-0.38438216],
#         [ 0.02644461]]))

# %%
x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

# min-max 0,1
sc = MinMaxScaler(feature_range=(0,1))
x = sc.fit_transform(x)
y = sc.fit_transform(y)

inputs = Input(shape=(1,))
preds = Dense(1,activation='linear')(inputs)

model = Model(inputs=inputs,outputs=preds)
sgd=keras.optimizers.SGD()
model.compile(optimizer=sgd ,loss='mse')
model.fit(x,y, batch_size=1, verbose=0, shuffle=False)
plt.scatter(x,y,color='black')
plt.plot(x,model.predict(x), color='blue', linewidth=3)

# %%
x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

# min-max -1,1
sc = MinMaxScaler(feature_range=(-1,1))
x = sc.fit_transform(x)
y = sc.fit_transform(y)

inputs = Input(shape=(1,))
preds = Dense(1,activation='linear')(inputs)

model = Model(inputs=inputs,outputs=preds)
sgd=keras.optimizers.SGD()
model.compile(optimizer=sgd ,loss='mse')
model.fit(x,y, batch_size=1, verbose=0, shuffle=False)
plt.scatter(x,y,color='black')
plt.plot(x,model.predict(x), color='blue', linewidth=3)

# %%
x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

# normalizer L1
sc = Normalizer(norm='l1')
x_ = sc.fit_transform(x)
y_ = sc.fit_transform(y)

inputs = Input(shape=(1,))
preds = Dense(1,activation='linear')(inputs)

model = Model(inputs=inputs,outputs=preds)
sgd=keras.optimizers.SGD()
model.compile(optimizer=sgd ,loss='mse')
model.fit(x_,y_, batch_size=1, verbose=0, shuffle=False)
plt.scatter(x_,y_,color='black')
plt.plot(x_,model.predict(x_), color='blue', linewidth=3)

# %%
x = df["People per Television"].values.reshape(-1,1)
y = df["People per Physician"].values.reshape(-1,1)

# normalizer L2
sc = Normalizer(norm='l2')
x = sc.fit_transform(x)
y = sc.fit_transform(y)

inputs = Input(shape=(1,))
preds = Dense(1,activation='linear')(inputs)

model = Model(inputs=inputs,outputs=preds)
sgd=keras.optimizers.SGD()
model.compile(optimizer=sgd ,loss='mse')
model.fit(x,y, batch_size=1, verbose=0, shuffle=False)
plt.scatter(x,y,color='black')
plt.plot(x,model.predict(x), color='blue', linewidth=3)
