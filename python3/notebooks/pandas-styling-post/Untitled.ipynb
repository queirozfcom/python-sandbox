# %%
import pandas as pd
pd.set_option("precision", 1)

# %%
df = pd.DataFrame(
    {
        "name":         ["alan","beth","charlie","david", "edward"],
        "age" :         [34,    12,    43,       32,      77],
        "num_children": [1,     0,     2,        1,       6],
        "num_pets":     [1,     0,     1,        2,       0],
        "bank_balance": [100.0, 10.0,  -10.0,    30.0,    30.0]})

# %%
df
# Out:
#       name  age  num_children  num_pets  bank_balance
# 0     alan   34             1         1         100.0
# 1     beth   12             0         0          10.0
# 2  charlie   43             2         1         -10.0
# 3    david   32             1         2          30.0
# 4   edward   77             6         0          30.0

# %% [markdown]
# ## elementwise

# %%
def even_number_background(cell_value):
    
    highlight = 'background-color: darkorange;'
    default = ''
    
    if type(cell_value) in [float, int]:
        if cell_value % 2 == 0:
            return highlight
    return default

# %%
styler = df.style.applymap(even_number_background)
styler
# Out:
# <style type="text/css">
# #T_c339c_row0_col1, #T_c339c_row0_col4, #T_c339c_row1_col1, #T_c339c_row1_col2, #T_c339c_row1_col3, #T_c339c_row1_col4, #T_c339c_row2_col2, #T_c339c_row2_col4, #T_c339c_row3_col1, #T_c339c_row3_col3, #T_c339c_row3_col4, #T_c339c_row4_col2, #T_c339c_row4_col3, #T_c339c_row4_col4 {
#   background-color: darkorange;
# }
# </style>
# <table id="T_c339c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >num_children</th>
#       <th class="col_heading level0 col3" >num_pets</th>
#       <th class="col_heading level0 col4" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c339c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c339c_row0_col0" class="data row0 col0" >alan</td>
#       <td id="T_c339c_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_c339c_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c339c_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c339c_row0_col4" class="data row0 col4" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_c339c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c339c_row1_col0" class="data row1 col0" >beth</td>
#       <td id="T_c339c_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_c339c_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c339c_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_c339c_row1_col4" class="data row1 col4" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_c339c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c339c_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_c339c_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_c339c_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_c339c_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_c339c_row2_col4" class="data row2 col4" >-10.0</td>
#     </tr>
#     <tr>
#       <th id="T_c339c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c339c_row3_col0" class="data row3 col0" >david</td>
#       <td id="T_c339c_row3_col1" class="data row3 col1" >32</td>
#       <td id="T_c339c_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_c339c_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c339c_row3_col4" class="data row3 col4" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_c339c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c339c_row4_col0" class="data row4 col0" >edward</td>
#       <td id="T_c339c_row4_col1" class="data row4 col1" >77</td>
#       <td id="T_c339c_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_c339c_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_c339c_row4_col4" class="data row4 col4" >30.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## rowwise

# %%
def more_children_or_more_pets_background(row):    
               
    highlight = 'background-color: lightcoral;'
    default = ''
    
    # must return one string per cell in this row
    if row['num_children'] > row['num_pets']:
        return [highlight, default]
    elif row['num_pets'] > row['num_children']:
        return [default, highlight]
    else:
        return [default, default]
    
df.style.apply(more_children_or_more_pets_background, subset=['num_children', 'num_pets'], axis=1)
# Out:
# <style type="text/css">
# #T_08553_row2_col2, #T_08553_row3_col3, #T_08553_row4_col2 {
#   background-color: lightcoral;
# }
# </style>
# <table id="T_08553_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >num_children</th>
#       <th class="col_heading level0 col3" >num_pets</th>
#       <th class="col_heading level0 col4" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08553_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_08553_row0_col0" class="data row0 col0" >alan</td>
#       <td id="T_08553_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_08553_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_08553_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_08553_row0_col4" class="data row0 col4" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_08553_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_08553_row1_col0" class="data row1 col0" >beth</td>
#       <td id="T_08553_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_08553_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_08553_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_08553_row1_col4" class="data row1 col4" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_08553_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_08553_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_08553_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_08553_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_08553_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_08553_row2_col4" class="data row2 col4" >-10.0</td>
#     </tr>
#     <tr>
#       <th id="T_08553_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_08553_row3_col0" class="data row3 col0" >david</td>
#       <td id="T_08553_row3_col1" class="data row3 col1" >32</td>
#       <td id="T_08553_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_08553_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_08553_row3_col4" class="data row3 col4" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_08553_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_08553_row4_col0" class="data row4 col0" >edward</td>
#       <td id="T_08553_row4_col1" class="data row4 col1" >77</td>
#       <td id="T_08553_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_08553_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_08553_row4_col4" class="data row4 col4" >30.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## columnwise

# %%
def maximum_value_in_column(column):    
               
    highlight = 'background-color: palegreen;'
    default = ''

    maximum_in_column = column.max()
    
    # must return one string per cell in this column
    return [highlight if v == maximum_in_column else default for v in column]
    
df.style.apply(maximum_value_in_column, subset=['num_children', 'num_pets'], axis=0)
# Out:
# <style type="text/css">
# #T_cd835_row3_col3, #T_cd835_row4_col2 {
#   background-color: palegreen;
# }
# </style>
# <table id="T_cd835_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >num_children</th>
#       <th class="col_heading level0 col3" >num_pets</th>
#       <th class="col_heading level0 col4" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cd835_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cd835_row0_col0" class="data row0 col0" >alan</td>
#       <td id="T_cd835_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_cd835_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_cd835_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_cd835_row0_col4" class="data row0 col4" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_cd835_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cd835_row1_col0" class="data row1 col0" >beth</td>
#       <td id="T_cd835_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_cd835_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_cd835_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_cd835_row1_col4" class="data row1 col4" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_cd835_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cd835_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_cd835_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_cd835_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_cd835_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_cd835_row2_col4" class="data row2 col4" >-10.0</td>
#     </tr>
#     <tr>
#       <th id="T_cd835_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cd835_row3_col0" class="data row3 col0" >david</td>
#       <td id="T_cd835_row3_col1" class="data row3 col1" >32</td>
#       <td id="T_cd835_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_cd835_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_cd835_row3_col4" class="data row3 col4" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_cd835_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cd835_row4_col0" class="data row4 col0" >edward</td>
#       <td id="T_cd835_row4_col1" class="data row4 col1" >77</td>
#       <td id="T_cd835_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_cd835_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_cd835_row4_col4" class="data row4 col4" >30.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## chained calls

# %%
# use red font for negative bank balances
# write the highest age in bold
# use light red background for zero values in num_children and num_pets

def red_font_negatives(series):
    highlight = 'color: red;'
    default = ''
    return [highlight if e < 0 else default for e in series]  

def bold_max_value_in_series(series):
    highlight = 'font-weight: bold;'
    default = ''
    
    return [highlight if e == series.max() else default for e in series]  

def red_background_zero_values(cell_value):
    highlight = 'background-color: red;'
    default = ''
    if cell_value == 0:
        return highlight
    else:
        return default     

(df
 .style
 .apply(red_font_negatives, axis=0, subset=['bank_balance'])
 .apply(bold_max_value_in_series, axis=0, subset=['age'])
 .applymap(red_background_zero_values))
# Out:
# <style type="text/css">
# #T_c8ee5_row1_col2, #T_c8ee5_row1_col3, #T_c8ee5_row4_col3 {
#   background-color: red;
# }
# #T_c8ee5_row2_col4 {
#   color: red;
# }
# #T_c8ee5_row4_col1 {
#   font-weight: bold;
# }
# </style>
# <table id="T_c8ee5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >age</th>
#       <th class="col_heading level0 col2" >num_children</th>
#       <th class="col_heading level0 col3" >num_pets</th>
#       <th class="col_heading level0 col4" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8ee5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8ee5_row0_col0" class="data row0 col0" >alan</td>
#       <td id="T_c8ee5_row0_col1" class="data row0 col1" >34</td>
#       <td id="T_c8ee5_row0_col2" class="data row0 col2" >1</td>
#       <td id="T_c8ee5_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_c8ee5_row0_col4" class="data row0 col4" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_c8ee5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c8ee5_row1_col0" class="data row1 col0" >beth</td>
#       <td id="T_c8ee5_row1_col1" class="data row1 col1" >12</td>
#       <td id="T_c8ee5_row1_col2" class="data row1 col2" >0</td>
#       <td id="T_c8ee5_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_c8ee5_row1_col4" class="data row1 col4" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_c8ee5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_c8ee5_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_c8ee5_row2_col1" class="data row2 col1" >43</td>
#       <td id="T_c8ee5_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_c8ee5_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_c8ee5_row2_col4" class="data row2 col4" >-10.0</td>
#     </tr>
#     <tr>
#       <th id="T_c8ee5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_c8ee5_row3_col0" class="data row3 col0" >david</td>
#       <td id="T_c8ee5_row3_col1" class="data row3 col1" >32</td>
#       <td id="T_c8ee5_row3_col2" class="data row3 col2" >1</td>
#       <td id="T_c8ee5_row3_col3" class="data row3 col3" >2</td>
#       <td id="T_c8ee5_row3_col4" class="data row3 col4" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_c8ee5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_c8ee5_row4_col0" class="data row4 col0" >edward</td>
#       <td id="T_c8ee5_row4_col1" class="data row4 col1" >77</td>
#       <td id="T_c8ee5_row4_col2" class="data row4 col2" >6</td>
#       <td id="T_c8ee5_row4_col3" class="data row4 col3" >0</td>
#       <td id="T_c8ee5_row4_col4" class="data row4 col4" >30.0</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## multiple colours

# %%
df = pd.DataFrame({
    "name":         ["alan","beth","charlie","david", "edward"],
    "bank_balance": [100.0, 10.0,   -10.0,   30.0,    30.0]})

def colour_numbers(series):
    red    = 'background-color: red;'
    orange = 'background-color: orange;' 
    
    default = ''
    
    return [red if e < 0 else orange if e < 15 else default for e in series]  


(df
 .style
 .apply(colour_numbers, axis=0, subset=['bank_balance']))
# Out:
# <style type="text/css">
# #T_13c61_row1_col1 {
#   background-color: orange;
# }
# #T_13c61_row2_col1 {
#   background-color: red;
# }
# </style>
# <table id="T_13c61_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >name</th>
#       <th class="col_heading level0 col1" >bank_balance</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13c61_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_13c61_row0_col0" class="data row0 col0" >alan</td>
#       <td id="T_13c61_row0_col1" class="data row0 col1" >100.0</td>
#     </tr>
#     <tr>
#       <th id="T_13c61_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_13c61_row1_col0" class="data row1 col0" >beth</td>
#       <td id="T_13c61_row1_col1" class="data row1 col1" >10.0</td>
#     </tr>
#     <tr>
#       <th id="T_13c61_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_13c61_row2_col0" class="data row2 col0" >charlie</td>
#       <td id="T_13c61_row2_col1" class="data row2 col1" >-10.0</td>
#     </tr>
#     <tr>
#       <th id="T_13c61_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_13c61_row3_col0" class="data row3 col0" >david</td>
#       <td id="T_13c61_row3_col1" class="data row3 col1" >30.0</td>
#     </tr>
#     <tr>
#       <th id="T_13c61_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_13c61_row4_col0" class="data row4 col0" >edward</td>
#       <td id="T_13c61_row4_col1" class="data row4 col1" >30.0</td>
#     </tr>
#   </tbody>
# </table>
