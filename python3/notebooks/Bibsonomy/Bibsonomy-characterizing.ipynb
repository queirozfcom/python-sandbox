# %% [markdown]
# > Information not found here can be found at [the mulan datasets web page](http://mulan.sourceforge.net/datasets-mlc.html)

# %%
import numpy as np
import scipy.sparse
import pandas as pd
from pandas import DataFrame,Series
from scipy.sparse import lil_matrix,vstack
from skmultilearn.dataset import Dataset

# %%
path = "/home/felipe/auto-tagger/data/bibsonomy/bookmarks.arff"

# %%
X, Y = Dataset.load_arff_to_numpy(path,labelcount=208,load_sparse=True)

# %%
X,Y
# Out:
# (<87856x2150 sparse matrix of type '<type 'numpy.int64'>'
#  	with 10198566 stored elements in LInked List format>,
#  <87856x208 sparse matrix of type '<type 'numpy.int64'>'
#  	with 1012228 stored elements in LInked List format>)

# %%
# using pandas to analyse the labelsets
df = DataFrame.from_records(Y.toarray())
num_unique_labelsets = len(df.drop_duplicates())
num_unique_labelsets
# Out:
# 53488

# %%
indices = Series(np.array(range(0,87856)), index = df.index)
df['id'] = indices
df
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#       <th>2</th>
#       <th>3</th>
#       <th>4</th>
#       <th>5</th>
#       <th>6</th>
#       <th>7</th>
#       <th>8</th>
#       <th>9</th>
#       <th>...</th>
#       <th>199</th>
#       <th>200</th>
#       <th>201</th>
#       <th>202</th>
#       <th>203</th>
#       <th>204</th>
#       <th>205</th>
#       <th>206</th>
#       <th>207</th>
#       <th>id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>...</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
# ...

# %%
grouped = df.groupby(list(range(0,208))).count()

# %%
num_labelsets_appearing_only_once = len(grouped[grouped['id']==1])
num_labelsets_appearing_only_once
# Out:
# 50267
